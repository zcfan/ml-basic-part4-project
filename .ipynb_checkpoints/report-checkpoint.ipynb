# %%
# 读入数据
# 数据解读页面：https://www.kaggle.com/c/titanic/data

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt


titanic = pd.read_csv('titanic-data.csv')

# %%
# 修正数据类型

# pd.read_csv 似乎已经做了一些数据类型猜测转换的工作，暂时先放下不管了。

print titanic
# print titanic['PassengerId']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# 我感兴趣的问题是：哪些因素可能增加乘客的幸存几率？

####################
# 首先尝试把幸存遇难分开，然后对比他们的每一项参数有哪些有明显差异，然后再仔细的观察这些差异明显的参数
####################

# 忽略直觉上无关的参数（不能完全否定相关性，但即使有相关的趋势，解释起来应该也很牵强）：Name, Ticket, Cabin(太多无效数据 NaN 了)

# 部分参数适合用平均值来对比
titanic_by_survived_mean = titanic[['PassengerId', 'Age', 'SibSp', 'Fare']].groupby('Survived').mean()

titanic_by_survived_mean

# 部分参数看成枚举型感觉更合适
titanic_by_survived = titanic[['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']].groupby('Survived')

titanic_by_survived

# 调查数据

# 找到问题

# 满足好奇心

#
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-96aa882275e4> in <module>()
#       8
#       9 # 部分参数适合用平均值来对比
# ---> 10 titanic_by_survived_mean = titanic[['PassengerId', 'Age', 'SibSp', 'Fare']].groupby('Survived').mean()
#      11
#      12 titanic_by_survived_mean
#
# /Users/alanzhang/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /Users/alanzhang/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
# ...

# %% [markdown]
# ##
#
# | Survived | PassengerId | Pclass   | Age       | SibSp    | Parch    | Fare      |
# | -------- | ----------- | -------- | --------- | -------- | -------- | --------- |
# | 0        | 447.016393  | 2.531876 | 30.626179 | 0.553734 | 0.329690 | 22.117887 |
# | 1        | 444.368421  | 1.950292 | 28.343690 | 0.473684 | 0.464912 | 48.395408 |
